# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime
from citipy import citipy
from config import weather_api_key

# %%
lats = np.random.uniform(-90,90,size=2000)
lngs = np.random.uniform(-180,180,size=2000)
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
print(f"Number of cities generated: {len(cities)}")
# Out:
# Number of cities generated: 731

# %%
# Build base url for api requests
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all cities
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_dscript = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_dscript})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kloulklubed
# Processing Record 2 of Set 1 | pevek
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | taguatinga
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | port blair
# Processing Record 8 of Set 1 | eydhafushi
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 1 | marawi
# Processing Record 13 of Set 1 | vardo
# Processing Record 14 of Set 1 | quatre cocos
# Processing Record 15 of Set 1 | tuatapere
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | rio grande
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | dunedin
# Processing Record 20 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | alta floresta
# Processing Record 23 of Set 1 | junqueiropolis
# Processing Record 24 of Set 1 | emerald
# Processing Record 25 of Set 1 | denpasar
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | kautokeino
# Processing Record 29 of Set 1 | pisco
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | vulcan
# Processing Record 32 of Set 1 | komsomolskiy
# Processing Record 33 of Set 1 | seoul
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | casper
# Processing Record 36 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | saint-andre-avellin
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | mormugao
# Processing Record 42 of Set 1 | zhigansk
# Processing Record 43 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | pacific grove
# Processing Record 47 of Set 1 | sinnamary
# Processing Record 48 of Set 1 | tual
# Processing Record 49 of Set 1 | bathsheba
# Processing Record 50 of Set 1 | kodiak
# Processing Record 1 of Set 2 | nisia floresta
# Processing Record 2 of Set 2 | matagami
# Processing Record 3 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 2 | barao de melgaco
# Processing Record 5 of Set 2 | neryungri
# Processing Record 6 of Set 2 | kupang
# Processing Record 7 of Set 2 | haimen
# Processing Record 8 of Set 2 | salvador
# Processing Record 9 of Set 2 | cayenne
# Processing Record 10 of Set 2 | airai
# Processing Record 11 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | paamiut
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | carnarvon
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | deneysville
# Processing Record 19 of Set 2 | norman wells
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | coihaique
# Processing Record 24 of Set 2 | fort nelson
# Processing Record 25 of Set 2 | buraydah
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | hobyo
# Processing Record 28 of Set 2 | vanavara
# Processing Record 29 of Set 2 | presidencia roque saenz pena
# Processing Record 30 of Set 2 | haines junction
# Processing Record 31 of Set 2 | itarema
# Processing Record 32 of Set 2 | north bend
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | mount gambier
# Processing Record 35 of Set 2 | shizunai
# Processing Record 36 of Set 2 | aksu
# Processing Record 37 of Set 2 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 38 of Set 2 | saravan
# Processing Record 39 of Set 2 | labuhan
# Processing Record 40 of Set 2 | ilulissat
# Processing Record 41 of Set 2 | changji
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | deputatskiy
# Processing Record 45 of Set 2 | yeehaw junction
# City not found. Skipping...
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 2 | voskresenskoye
# Processing Record 49 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 2 | ostrovnoy
# Processing Record 1 of Set 3 | victoria
# Processing Record 2 of Set 3 | saint-pierre
# Processing Record 3 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 3 | guerrero negro
# Processing Record 5 of Set 3 | arraial do cabo
# Processing Record 6 of Set 3 | halifax
# Processing Record 7 of Set 3 | bubaque
# Processing Record 8 of Set 3 | kiruna
# Processing Record 9 of Set 3 | kaeo
# Processing Record 10 of Set 3 | port lincoln
# Processing Record 11 of Set 3 | clyde river
# Processing Record 12 of Set 3 | dryden
# Processing Record 13 of Set 3 | alta
# Processing Record 14 of Set 3 | nkan
# Processing Record 15 of Set 3 | saint-leu
# Processing Record 16 of Set 3 | luderitz
# Processing Record 17 of Set 3 | sirjan
# Processing Record 18 of Set 3 | leshukonskoye
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | sakhon nakhon
# Processing Record 21 of Set 3 | esperance
# Processing Record 22 of Set 3 | mataura
# Processing Record 23 of Set 3 | lugovoy
# Processing Record 24 of Set 3 | chokurdakh
# Processing Record 25 of Set 3 | prabumulih
# Processing Record 26 of Set 3 | san patricio
# Processing Record 27 of Set 3 | hambantota
# Processing Record 28 of Set 3 | vao
# Processing Record 29 of Set 3 | mabaruma
# Processing Record 30 of Set 3 | channel-port aux basques
# Processing Record 31 of Set 3 | siavonga
# Processing Record 32 of Set 3 | pangkalanbuun
# Processing Record 33 of Set 3 | kodinsk
# Processing Record 34 of Set 3 | juigalpa
# Processing Record 35 of Set 3 | natal
# Processing Record 36 of Set 3 | te anau
# Processing Record 37 of Set 3 | salalah
# Processing Record 38 of Set 3 | mnogovershinnyy
# Processing Record 39 of Set 3 | hilo
# Processing Record 40 of Set 3 | puerto ayora
# Processing Record 41 of Set 3 | ust-koksa
# Processing Record 42 of Set 3 | cherskiy
# Processing Record 43 of Set 3 | mount pleasant
# Processing Record 44 of Set 3 | balabac
# Processing Record 45 of Set 3 | escarcega
# Processing Record 46 of Set 3 | zverinogolovskoye
# Processing Record 47 of Set 3 | sterling
# Processing Record 48 of Set 3 | aljezur
# Processing Record 49 of Set 3 | tres arroyos
# Processing Record 50 of Set 3 | hithadhoo
# Processing Record 1 of Set 4 | santa marta
# Processing Record 2 of Set 4 | kavieng
# Processing Record 3 of Set 4 | weihe
# Processing Record 4 of Set 4 | itoman
# Processing Record 5 of Set 4 | lahij
# Processing Record 6 of Set 4 | abnub
# Processing Record 7 of Set 4 | timmins
# Processing Record 8 of Set 4 | namibe
# Processing Record 9 of Set 4 | barrow
# Processing Record 10 of Set 4 | lac-megantic
# Processing Record 11 of Set 4 | kyle
# Processing Record 12 of Set 4 | iqaluit
# Processing Record 13 of Set 4 | cabo san lucas
# Processing Record 14 of Set 4 | ossora
# Processing Record 15 of Set 4 | potiskum
# Processing Record 16 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 4 | grand gaube
# Processing Record 18 of Set 4 | del rio
# Processing Record 19 of Set 4 | kruisfontein
# Processing Record 20 of Set 4 | bluff
# Processing Record 21 of Set 4 | taoudenni
# Processing Record 22 of Set 4 | ramhormoz
# Processing Record 23 of Set 4 | aswan
# Processing Record 24 of Set 4 | anuradhapura
# Processing Record 25 of Set 4 | biltine
# Processing Record 26 of Set 4 | mangai
# Processing Record 27 of Set 4 | bowral
# Processing Record 28 of Set 4 | lukovetskiy
# Processing Record 29 of Set 4 | kaitangata
# Processing Record 30 of Set 4 | vila franca do campo
# Processing Record 31 of Set 4 | gao
# Processing Record 32 of Set 4 | sistranda
# Processing Record 33 of Set 4 | lavrentiya
# Processing Record 34 of Set 4 | mama
# Processing Record 35 of Set 4 | arlit
# Processing Record 36 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 4 | wanning
# Processing Record 39 of Set 4 | elko
# Processing Record 40 of Set 4 | irbid
# Processing Record 41 of Set 4 | livingston
# Processing Record 42 of Set 4 | paramonga
# Processing Record 43 of Set 4 | kinsale
# Processing Record 44 of Set 4 | berdigestyakh
# Processing Record 45 of Set 4 | yellowknife
# Processing Record 46 of Set 4 | touros
# Processing Record 47 of Set 4 | ponta do sol
# Processing Record 48 of Set 4 | jaisalmer
# Processing Record 49 of Set 4 | tibati
# Processing Record 50 of Set 4 | saint george
# Processing Record 1 of Set 5 | lebu
# Processing Record 2 of Set 5 | souillac
# Processing Record 3 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 4 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 5 of Set 5 | ukiah
# Processing Record 6 of Set 5 | alofi
# Processing Record 7 of Set 5 | banjar
# Processing Record 8 of Set 5 | omboue
# Processing Record 9 of Set 5 | upernavik
# Processing Record 10 of Set 5 | prainha
# Processing Record 11 of Set 5 | maceio
# Processing Record 12 of Set 5 | jalu
# Processing Record 13 of Set 5 | klaksvik
# Processing Record 14 of Set 5 | coquimbo
# Processing Record 15 of Set 5 | tiksi
# Processing Record 16 of Set 5 | lata
# Processing Record 17 of Set 5 | thompson
# Processing Record 18 of Set 5 | dianopolis
# City not found. Skipping...
# Processing Record 19 of Set 5 | bereda
# Processing Record 20 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 5 | bambous virieux
# Processing Record 22 of Set 5 | severo-kurilsk
# Processing Record 23 of Set 5 | banda aceh
# Processing Record 24 of Set 5 | bure
# Processing Record 25 of Set 5 | faanui
# Processing Record 26 of Set 5 | coahuayana
# Processing Record 27 of Set 5 | mehamn
# Processing Record 28 of Set 5 | chermen
# Processing Record 29 of Set 5 | san juan evangelista
# Processing Record 30 of Set 5 | pilar
# Processing Record 31 of Set 5 | katsuura
# Processing Record 32 of Set 5 | upata
# Processing Record 33 of Set 5 | dauphin
# Processing Record 34 of Set 5 | lagoa
# Processing Record 35 of Set 5 | inta
# Processing Record 36 of Set 5 | port hardy
# Processing Record 37 of Set 5 | sinop
# Processing Record 38 of Set 5 | gallup
# Processing Record 39 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 5 | leca da palmeira
# Processing Record 41 of Set 5 | ekhabi
# Processing Record 42 of Set 5 | kendal
# Processing Record 43 of Set 5 | tilichiki
# Processing Record 44 of Set 5 | jaru
# Processing Record 45 of Set 5 | turukhansk
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 5 | hasaki
# Processing Record 49 of Set 5 | gorontalo
# Processing Record 50 of Set 5 | poya
# Processing Record 1 of Set 6 | obo
# Processing Record 2 of Set 6 | tazovskiy
# Processing Record 3 of Set 6 | karratha
# Processing Record 4 of Set 6 | neepawa
# Processing Record 5 of Set 6 | antofagasta
# Processing Record 6 of Set 6 | torbay
# Processing Record 7 of Set 6 | talnakh
# Processing Record 8 of Set 6 | laguna
# Processing Record 9 of Set 6 | castro
# Processing Record 10 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 6 | surab
# Processing Record 12 of Set 6 | fortuna
# Processing Record 13 of Set 6 | brigantine
# Processing Record 14 of Set 6 | qaanaaq
# Processing Record 15 of Set 6 | tartagal
# Processing Record 16 of Set 6 | yar-sale
# Processing Record 17 of Set 6 | san jose
# Processing Record 18 of Set 6 | belaya gora
# Processing Record 19 of Set 6 | nemuro
# Processing Record 20 of Set 6 | geraldton
# Processing Record 21 of Set 6 | kuala terengganu
# Processing Record 22 of Set 6 | novo aripuana
# Processing Record 23 of Set 6 | kahului
# Processing Record 24 of Set 6 | villanueva de la serena
# Processing Record 25 of Set 6 | rovaniemi
# Processing Record 26 of Set 6 | porto seguro
# Processing Record 27 of Set 6 | mareeba
# Processing Record 28 of Set 6 | magomeni
# Processing Record 29 of Set 6 | lensk
# Processing Record 30 of Set 6 | qrendi
# Processing Record 31 of Set 6 | goderich
# Processing Record 32 of Set 6 | meulaboh
# Processing Record 33 of Set 6 | port-gentil
# Processing Record 34 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 35 of Set 6 | yuksekova
# Processing Record 36 of Set 6 | singaraja
# Processing Record 37 of Set 6 | delmas
# Processing Record 38 of Set 6 | falam
# Processing Record 39 of Set 6 | gupitan
# Processing Record 40 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 6 | kavaratti
# Processing Record 42 of Set 6 | waren
# Processing Record 43 of Set 6 | kalmunai
# Processing Record 44 of Set 6 | knysna
# Processing Record 45 of Set 6 | santiago de cao
# Processing Record 46 of Set 6 | diffa
# Processing Record 47 of Set 6 | hede
# Processing Record 48 of Set 6 | mantua
# Processing Record 49 of Set 6 | saskylakh
# Processing Record 50 of Set 6 | yurimaguas
# Processing Record 1 of Set 7 | mount isa
# Processing Record 2 of Set 7 | rab
# City not found. Skipping...
# Processing Record 3 of Set 7 | evensk
# Processing Record 4 of Set 7 | san juan
# Processing Record 5 of Set 7 | nome
# Processing Record 6 of Set 7 | tabuk
# Processing Record 7 of Set 7 | leningradskiy
# Processing Record 8 of Set 7 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 9 of Set 7 | hamilton
# Processing Record 10 of Set 7 | igrim
# Processing Record 11 of Set 7 | kindu
# Processing Record 12 of Set 7 | koumac
# Processing Record 13 of Set 7 | okhotsk
# Processing Record 14 of Set 7 | port elizabeth
# Processing Record 15 of Set 7 | chuy
# Processing Record 16 of Set 7 | hofn
# Processing Record 17 of Set 7 | maddela
# Processing Record 18 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 7 | avera
# Processing Record 21 of Set 7 | tambopata
# Processing Record 22 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 7 | faro
# Processing Record 24 of Set 7 | mayo
# Processing Record 25 of Set 7 | ryotsu
# Processing Record 26 of Set 7 | tucupita
# Processing Record 27 of Set 7 | pangnirtung
# Processing Record 28 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 7 | olafsvik
# Processing Record 30 of Set 7 | charters towers
# Processing Record 31 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 32 of Set 7 | eureka
# Processing Record 33 of Set 7 | tingrela
# City not found. Skipping...
# Processing Record 34 of Set 7 | taburao
# City not found. Skipping...
# Processing Record 35 of Set 7 | ambon
# Processing Record 36 of Set 7 | saldanha
# Processing Record 37 of Set 7 | provideniya
# Processing Record 38 of Set 7 | kemnay
# Processing Record 39 of Set 7 | harper
# Processing Record 40 of Set 7 | patea
# Processing Record 41 of Set 7 | sao filipe
# Processing Record 42 of Set 7 | gardan diwal
# City not found. Skipping...
# Processing Record 43 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 44 of Set 7 | itambacuri
# Processing Record 45 of Set 7 | havre-saint-pierre
# Processing Record 46 of Set 7 | west odessa
# Processing Record 47 of Set 7 | ribeira grande
# Processing Record 48 of Set 7 | kurilsk
# Processing Record 49 of Set 7 | yumen
# Processing Record 50 of Set 7 | nikolskoye
# Processing Record 1 of Set 8 | arkhangelskoye
# Processing Record 2 of Set 8 | tafresh
# Processing Record 3 of Set 8 | sorland
# Processing Record 4 of Set 8 | mecca
# Processing Record 5 of Set 8 | san clemente
# Processing Record 6 of Set 8 | adre
# Processing Record 7 of Set 8 | nouadhibou
# Processing Record 8 of Set 8 | naryan-mar
# Processing Record 9 of Set 8 | nortelandia
# Processing Record 10 of Set 8 | ballina
# Processing Record 11 of Set 8 | boditi
# Processing Record 12 of Set 8 | chapais
# Processing Record 13 of Set 8 | victor harbor
# Processing Record 14 of Set 8 | fengrun
# Processing Record 15 of Set 8 | yulara
# Processing Record 16 of Set 8 | mumford
# Processing Record 17 of Set 8 | sabalgarh
# Processing Record 18 of Set 8 | gizo
# Processing Record 19 of Set 8 | walvis bay
# Processing Record 20 of Set 8 | taua
# Processing Record 21 of Set 8 | lompoc
# Processing Record 22 of Set 8 | camacupa
# Processing Record 23 of Set 8 | concarneau
# Processing Record 24 of Set 8 | korla
# Processing Record 25 of Set 8 | tanete
# Processing Record 26 of Set 8 | asau
# Processing Record 27 of Set 8 | bilibino
# Processing Record 28 of Set 8 | neiafu
# Processing Record 29 of Set 8 | saint anthony
# Processing Record 30 of Set 8 | pyaozerskiy
# Processing Record 31 of Set 8 | oga
# Processing Record 32 of Set 8 | bolshaya glushitsa
# Processing Record 33 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 8 | san policarpo
# Processing Record 35 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 8 | balykshi
# Processing Record 37 of Set 8 | jhudo
# Processing Record 38 of Set 8 | beachwood
# Processing Record 39 of Set 8 | batemans bay
# Processing Record 40 of Set 8 | reserva
# Processing Record 41 of Set 8 | desbiens
# Processing Record 42 of Set 8 | kenai
# Processing Record 43 of Set 8 | pobe
# Processing Record 44 of Set 8 | noumea
# Processing Record 45 of Set 8 | biak
# Processing Record 46 of Set 8 | trincomalee
# Processing Record 47 of Set 8 | ancud
# Processing Record 48 of Set 8 | dawei
# Processing Record 49 of Set 8 | russell
# Processing Record 50 of Set 8 | alpena
# Processing Record 1 of Set 9 | egvekinot
# Processing Record 2 of Set 9 | san cristobal
# Processing Record 3 of Set 9 | eyl
# Processing Record 4 of Set 9 | chifeng
# Processing Record 5 of Set 9 | deyang
# Processing Record 6 of Set 9 | bandarbeyla
# Processing Record 7 of Set 9 | gari
# Processing Record 8 of Set 9 | tura
# Processing Record 9 of Set 9 | rocha
# Processing Record 10 of Set 9 | rio gallegos
# Processing Record 11 of Set 9 | hovd
# Processing Record 12 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 13 of Set 9 | sujiatun
# Processing Record 14 of Set 9 | sikar
# Processing Record 15 of Set 9 | sur
# Processing Record 16 of Set 9 | faya
# Processing Record 17 of Set 9 | tangjiazhuang
# Processing Record 18 of Set 9 | tondela
# Processing Record 19 of Set 9 | kozhva
# Processing Record 20 of Set 9 | alugan
# Processing Record 21 of Set 9 | nouakchott
# Processing Record 22 of Set 9 | necochea
# Processing Record 23 of Set 9 | snasa
# Processing Record 24 of Set 9 | yumbe
# Processing Record 25 of Set 9 | general roca
# Processing Record 26 of Set 9 | apple valley
# Processing Record 27 of Set 9 | pafos
# Processing Record 28 of Set 9 | manggar
# Processing Record 29 of Set 9 | los llanos de aridane
# Processing Record 30 of Set 9 | vila velha
# Processing Record 31 of Set 9 | lalomanu
# City not found. Skipping...
# Processing Record 32 of Set 9 | dingle
# Processing Record 33 of Set 9 | san quintin
# Processing Record 34 of Set 9 | trofors
# Processing Record 35 of Set 9 | saurimo
# Processing Record 36 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 9 | morondava
# Processing Record 38 of Set 9 | comodoro rivadavia
# Processing Record 39 of Set 9 | tonder
# Processing Record 40 of Set 9 | maryville
# Processing Record 41 of Set 9 | hasanabad
# Processing Record 42 of Set 9 | arman
# Processing Record 43 of Set 9 | portland
# Processing Record 44 of Set 9 | margate
# Processing Record 45 of Set 9 | pabrade
# Processing Record 46 of Set 9 | swift current
# Processing Record 47 of Set 9 | miraflores
# Processing Record 48 of Set 9 | college
# Processing Record 49 of Set 9 | birobidzhan
# Processing Record 50 of Set 9 | plugari
# Processing Record 1 of Set 10 | richards bay
# Processing Record 2 of Set 10 | vestmannaeyjar
# Processing Record 3 of Set 10 | harnosand
# Processing Record 4 of Set 10 | dongsheng
# Processing Record 5 of Set 10 | maruim
# Processing Record 6 of Set 10 | gonaives
# Processing Record 7 of Set 10 | tautira
# Processing Record 8 of Set 10 | kenora
# Processing Record 9 of Set 10 | valdivia
# Processing Record 10 of Set 10 | bara
# Processing Record 11 of Set 10 | oranjemund
# Processing Record 12 of Set 10 | santiago del estero
# Processing Record 13 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 10 | aklavik
# Processing Record 15 of Set 10 | savelugu
# Processing Record 16 of Set 10 | namie
# Processing Record 17 of Set 10 | mapiripan
# Processing Record 18 of Set 10 | tukrah
# Processing Record 19 of Set 10 | griffith
# Processing Record 20 of Set 10 | motygino
# Processing Record 21 of Set 10 | cedar city
# Processing Record 22 of Set 10 | roebourne
# Processing Record 23 of Set 10 | fundao
# Processing Record 24 of Set 10 | abu samrah
# Processing Record 25 of Set 10 | yokadouma
# Processing Record 26 of Set 10 | popondetta
# Processing Record 27 of Set 10 | bengkulu
# Processing Record 28 of Set 10 | la democracia
# Processing Record 29 of Set 10 | kushmurun
# Processing Record 30 of Set 10 | brae
# Processing Record 31 of Set 10 | mao
# Processing Record 32 of Set 10 | cortez
# Processing Record 33 of Set 10 | clarence town
# Processing Record 34 of Set 10 | srednekolymsk
# Processing Record 35 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 10 | ballaghaderreen
# Processing Record 37 of Set 10 | palmer
# Processing Record 38 of Set 10 | radzyn podlaski
# Processing Record 39 of Set 10 | honningsvag
# Processing Record 40 of Set 10 | svetlogorsk
# Processing Record 41 of Set 10 | axim
# Processing Record 42 of Set 10 | ishurdi
# Processing Record 43 of Set 10 | paita
# Processing Record 44 of Set 10 | san rafael
# Processing Record 45 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 10 | muros
# Processing Record 47 of Set 10 | capreol
# Processing Record 48 of Set 10 | strezhevoy
# Processing Record 49 of Set 10 | constantine
# Processing Record 50 of Set 10 | port-cartier
# Processing Record 1 of Set 11 | ouadda
# Processing Record 2 of Set 11 | serov
# Processing Record 3 of Set 11 | zabinka
# City not found. Skipping...
# Processing Record 4 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 5 of Set 11 | achit
# Processing Record 6 of Set 11 | la ronge
# Processing Record 7 of Set 11 | ulaangom
# Processing Record 8 of Set 11 | ahipara
# Processing Record 9 of Set 11 | port hedland
# Processing Record 10 of Set 11 | sydney
# Processing Record 11 of Set 11 | qaqortoq
# Processing Record 12 of Set 11 | sayyan
# Processing Record 13 of Set 11 | zacatepec
# Processing Record 14 of Set 11 | manali
# Processing Record 15 of Set 11 | alta gracia
# Processing Record 16 of Set 11 | guilin
# Processing Record 17 of Set 11 | puerto baquerizo moreno
# Processing Record 18 of Set 11 | grants
# Processing Record 19 of Set 11 | lovozero
# Processing Record 20 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 11 | hounde
# Processing Record 22 of Set 11 | dunda
# Processing Record 23 of Set 11 | garm
# City not found. Skipping...
# Processing Record 24 of Set 11 | zhaotong
# Processing Record 25 of Set 11 | clarksburg
# Processing Record 26 of Set 11 | bom jesus
# Processing Record 27 of Set 11 | innisfail
# Processing Record 28 of Set 11 | hervey bay
# Processing Record 29 of Set 11 | redding
# Processing Record 30 of Set 11 | antalaha
# Processing Record 31 of Set 11 | kuryk
# Processing Record 32 of Set 11 | cangzhou
# Processing Record 33 of Set 11 | qasigiannguit
# Processing Record 34 of Set 11 | manga
# Processing Record 35 of Set 11 | willowmore
# Processing Record 36 of Set 11 | malm
# Processing Record 37 of Set 11 | atbasar
# Processing Record 38 of Set 11 | shimoda
# Processing Record 39 of Set 11 | tiarei
# Processing Record 40 of Set 11 | baruun-urt
# Processing Record 41 of Set 11 | sosnovo-ozerskoye
# Processing Record 42 of Set 11 | havre
# Processing Record 43 of Set 11 | estelle
# Processing Record 44 of Set 11 | sukumo
# Processing Record 45 of Set 11 | irtyshskiy
# Processing Record 46 of Set 11 | camacha
# Processing Record 47 of Set 11 | sheridan
# Processing Record 48 of Set 11 | icod de los vinos
# Processing Record 49 of Set 11 | lasa
# Processing Record 50 of Set 11 | gudari
# Processing Record 1 of Set 12 | chingirlau
# Processing Record 2 of Set 12 | orotukan
# Processing Record 3 of Set 12 | port moresby
# Processing Record 4 of Set 12 | acarau
# Processing Record 5 of Set 12 | asind
# Processing Record 6 of Set 12 | polson
# Processing Record 7 of Set 12 | huatulco
# Processing Record 8 of Set 12 | zilupe
# Processing Record 9 of Set 12 | nikolayevsk-na-amure
# Processing Record 10 of Set 12 | altamira
# Processing Record 11 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 12 | juneau
# Processing Record 13 of Set 12 | severnyy
# Processing Record 14 of Set 12 | killam
# Processing Record 15 of Set 12 | schertz
# Processing Record 16 of Set 12 | kourou
# Processing Record 17 of Set 12 | chipata
# Processing Record 18 of Set 12 | pandan
# Processing Record 19 of Set 12 | bac lieu
# Processing Record 20 of Set 12 | timizart
# Processing Record 21 of Set 12 | vostok
# Processing Record 22 of Set 12 | martil
# Processing Record 23 of Set 12 | noblesville
# Processing Record 24 of Set 12 | alice
# Processing Record 25 of Set 12 | atka
# City not found. Skipping...
# Processing Record 26 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 27 of Set 12 | amuntai
# Processing Record 28 of Set 12 | guanajuato
# Processing Record 29 of Set 12 | khabary
# Processing Record 30 of Set 12 | manokwari
# Processing Record 31 of Set 12 | kawalu
# Processing Record 32 of Set 12 | santa maria
# Processing Record 33 of Set 12 | cockburn town
# Processing Record 34 of Set 12 | peleduy
# Processing Record 35 of Set 12 | behbahan
# Processing Record 36 of Set 12 | shakawe
# Processing Record 37 of Set 12 | inongo
# Processing Record 38 of Set 12 | caravelas
# Processing Record 39 of Set 12 | katherine
# Processing Record 40 of Set 12 | sidney
# Processing Record 41 of Set 12 | tricase
# Processing Record 42 of Set 12 | pavlikeni
# Processing Record 43 of Set 12 | baykit
# Processing Record 44 of Set 12 | petilia policastro
# Processing Record 45 of Set 12 | pemangkat
# Processing Record 46 of Set 12 | siria
# Processing Record 47 of Set 12 | jertih
# Processing Record 48 of Set 12 | fairbanks
# Processing Record 49 of Set 12 | magadan
# Processing Record 50 of Set 12 | kambove
# Processing Record 1 of Set 13 | xiaoweizhai
# Processing Record 2 of Set 13 | beira
# Processing Record 3 of Set 13 | alghero
# Processing Record 4 of Set 13 | dzilam gonzalez
# Processing Record 5 of Set 13 | demirci
# Processing Record 6 of Set 13 | inhambane
# Processing Record 7 of Set 13 | sarab
# Processing Record 8 of Set 13 | mbandaka
# Processing Record 9 of Set 13 | prado
# Processing Record 10 of Set 13 | kulhudhuffushi
# Processing Record 11 of Set 13 | bhinga
# Processing Record 12 of Set 13 | alice springs
# Processing Record 13 of Set 13 | kalabo
# Processing Record 14 of Set 13 | barra
# Processing Record 15 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 16 of Set 13 | san ignacio
# Processing Record 17 of Set 13 | berlevag
# Processing Record 18 of Set 13 | cidreira
# Processing Record 19 of Set 13 | kamenka
# Processing Record 20 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 13 | beppu
# Processing Record 23 of Set 13 | chardara
# Processing Record 24 of Set 13 | alappuzha
# Processing Record 25 of Set 13 | esso
# Processing Record 26 of Set 13 | garbolovo
# Processing Record 27 of Set 13 | belyy yar
# Processing Record 28 of Set 13 | havelock
# Processing Record 29 of Set 13 | gilgit
# Processing Record 30 of Set 13 | adwa
# Processing Record 31 of Set 13 | trairi
# Processing Record 32 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 33 of Set 13 | chicama
# Processing Record 34 of Set 13 | sioux lookout
# Processing Record 35 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 36 of Set 13 | tobermory
# Processing Record 37 of Set 13 | andra
# Processing Record 38 of Set 13 | riyadh
# Processing Record 39 of Set 13 | mannheim
# Processing Record 40 of Set 13 | terrace bay
# Processing Record 41 of Set 13 | cozumel
# Processing Record 42 of Set 13 | whitehorse
# Processing Record 43 of Set 13 | iskateley
# Processing Record 44 of Set 13 | kijang
# Processing Record 45 of Set 13 | west wendover
# Processing Record 46 of Set 13 | santa cruz de la palma
# Processing Record 47 of Set 13 | hassleholm
# Processing Record 48 of Set 13 | voh
# Processing Record 49 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 13 | gaspe
# Processing Record 1 of Set 14 | loyga
# Processing Record 2 of Set 14 | verkhovazhye
# Processing Record 3 of Set 14 | saryg-sep
# Processing Record 4 of Set 14 | grindavik
# Processing Record 5 of Set 14 | anloga
# Processing Record 6 of Set 14 | yinchuan
# Processing Record 7 of Set 14 | tsabong
# Processing Record 8 of Set 14 | tateyama
# Processing Record 9 of Set 14 | praxedis guerrero
# Processing Record 10 of Set 14 | ostersund
# Processing Record 11 of Set 14 | juru
# Processing Record 12 of Set 14 | kiunga
# Processing Record 13 of Set 14 | moron
# Processing Record 14 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 14 | mae sai
# Processing Record 16 of Set 14 | wicklow
# Processing Record 17 of Set 14 | mongoumba
# Processing Record 18 of Set 14 | belmonte
# Processing Record 19 of Set 14 | hallingby
# City not found. Skipping...
# Processing Record 20 of Set 14 | marsaxlokk
# Processing Record 21 of Set 14 | maragogi
# Processing Record 22 of Set 14 | bairiki
# Processing Record 23 of Set 14 | mandalgovi
# Processing Record 24 of Set 14 | ahuimanu
# Processing Record 25 of Set 14 | half moon bay
# Processing Record 26 of Set 14 | batsfjord
# Processing Record 27 of Set 14 | diego de almagro
# Processing Record 28 of Set 14 | bintulu
# Processing Record 29 of Set 14 | vinh
# Processing Record 30 of Set 14 | havoysund
# Processing Record 31 of Set 14 | kungurtug
# Processing Record 32 of Set 14 | aykhal
# Processing Record 33 of Set 14 | sola
# Processing Record 34 of Set 14 | ola
# Processing Record 35 of Set 14 | beatrice
# Processing Record 36 of Set 14 | general pico
# Processing Record 37 of Set 14 | ketchikan
# Processing Record 38 of Set 14 | vicar
# Processing Record 39 of Set 14 | lodeynoye pole
# Processing Record 40 of Set 14 | am timan
# Processing Record 41 of Set 14 | tongren
# Processing Record 42 of Set 14 | novobessergenevka
# Processing Record 43 of Set 14 | roma
# Processing Record 44 of Set 14 | abha
# Processing Record 45 of Set 14 | suffolk
# Processing Record 46 of Set 14 | taltal
# Processing Record 47 of Set 14 | zaysan
# Processing Record 48 of Set 14 | gazojak
# Processing Record 49 of Set 14 | along
# Processing Record 50 of Set 14 | jimma
# Processing Record 1 of Set 15 | whitianga
# Processing Record 2 of Set 15 | atlantic city
# Processing Record 3 of Set 15 | mardin
# Processing Record 4 of Set 15 | tutoia
# Processing Record 5 of Set 15 | manzhouli
# Processing Record 6 of Set 15 | sai buri
# Processing Record 7 of Set 15 | banovce
# City not found. Skipping...
# Processing Record 8 of Set 15 | nuuk
# Processing Record 9 of Set 15 | burica
# City not found. Skipping...
# Processing Record 10 of Set 15 | kokopo
# Processing Record 11 of Set 15 | tunduma
# Processing Record 12 of Set 15 | bonfim
# Processing Record 13 of Set 15 | henties bay
# Processing Record 14 of Set 15 | birjand
# Processing Record 15 of Set 15 | acapulco
# Processing Record 16 of Set 15 | waipawa
# Processing Record 17 of Set 15 | vilyuysk
# Processing Record 18 of Set 15 | eenhana
# Processing Record 19 of Set 15 | huilong
# Processing Record 20 of Set 15 | leh
# Processing Record 21 of Set 15 | varhaug
# Processing Record 22 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 23 of Set 15 | mayor pablo lagerenza
# Processing Record 24 of Set 15 | hudson bay
# Processing Record 25 of Set 15 | mosalsk
# Processing Record 26 of Set 15 | arco
# Processing Record 27 of Set 15 | watsa
# Processing Record 28 of Set 15 | narsaq
# Processing Record 29 of Set 15 | hay river
# Processing Record 30 of Set 15 | peschanokopskoye
# Processing Record 31 of Set 15 | limbang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Kloulklubed      PW   7.0419  134.2556     84.61        74         100
# 1        Pevek      RU  69.7008  170.3133     32.99        96          96
# 2   Bredasdorp      ZA -34.5322   20.0403     65.52        55          69
# 3        Vaini      TO -21.2000 -175.2000     71.76        83          75
# 4   Taguatinga      BR -12.3857  -46.5711     67.75        64          53
# 5       Albany      US  42.6001  -73.9662     59.04        89          43
# 6   Port Blair      IN  11.6667   92.7500     82.98        80         100
# 7   Eydhafushi      MV   5.1033   73.0708     82.27        76          86
# 8    Busselton      AU -33.6500  115.3333     51.04        65           8
# 9       Bethel      US  41.3712  -73.4140     60.03        90           1
#
#    Wind Speed Current Description
# 0       12.35     overcast clouds
# 1       16.46     overcast clouds
# 2       14.97       broken clouds
# 3       23.02          light rain
# 4        8.08       broken clouds
# 5        3.38    scattered clouds
# 6       19.57     overcast clouds
# 7       10.60     overcast clouds
# 8       12.06           clear sky
# 9        0.00           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
